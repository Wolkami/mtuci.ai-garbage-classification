# %%
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt

img_path = Path("../runs/efficientnet_b0/confusion_matrix.png")
img = Image.open(img_path)

plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Наиболее частые ошибки модели связаны с классами glass, plastic и other.
# Например, цветные прозрачные стеклянные бутылки могут быть ошибочно отнесены к пластику, поскольку имеют похожую форму, прозрачность и цвет.
# Также класс other является наиболее разнородным, поэтому часть объектов из paper и plastic может ошибочно попадать в него.
