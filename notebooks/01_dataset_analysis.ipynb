# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = Path("../data/processed")

rows = []

for split in ["train", "val", "test"]:
    for class_dir in sorted((DATA_DIR / split).iterdir()):
        if class_dir.is_dir():
            count = len(list(class_dir.glob("*")))
            rows.append({
                "split": split,
                "class": class_dir.name,
                "count": count,
            })

df = pd.DataFrame(rows)
df
# Out:
#     split      class  count
# 0   train  cardboard    700
# 1   train      glass   1050
# 2   train      metal   1400
# 3   train      other   2800
# 4   train      paper   1400
# 5   train    plastic   3150
# 6     val  cardboard    150
# 7     val      glass    225
# 8     val      metal    300
# 9     val      other    600
# 10    val      paper    300
# 11    val    plastic    675
# 12   test  cardboard    150
# 13   test      glass    225
# 14   test      metal    300
# 15   test      other    600
# 16   test      paper    300
# 17   test    plastic    675

# %%
pivot = df.pivot(index="class", columns="split", values="count")

pivot.plot(kind="bar", figsize=(10, 5))
plt.title("Распределение изображений по классам")
plt.xlabel("Класс")
plt.ylabel("Количество изображений")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
